# %%
import gymnasium as gym # Environment interface
from stable_baselines3 import DQN # Library for RL agorithms
from stable_baselines3.dqn import MlpPolicy #

env = gym.make("CartPole-v1") # Creates the env, train without rendering (si it's faster!)

model = DQN( # Change the hyperparamaters for better results
    MlpPolicy,
    env,
    learning_rate=1e-3,  # default: 1e-4; CartPole often benefits from faster learning
    buffer_size=50000,   # default is 100,000; reduce if memory constrained
    learning_starts=1000,  # allow model to populate replay buffer before training
    batch_size=64,  # bigger batches can stabilize training
    tau=1.0,  # hard update for target network
    gamma=0.99,  # discount factor
    train_freq=4,  # train every 4 steps
    target_update_interval=1000,  # how often to update target network
    exploration_fraction=0.1,  # fraction of total_timesteps where exploration rate is annealed
    exploration_final_eps=0.02,  # final epsilon
    verbose=1
)

model.learn(total_timesteps=10000) # Train the model for 100,000 steps

render_env = gym.make("CartPole-v1", render_mode="human") # Create a new env with rendering for watching

# Run trained model and only render after trainig 
num_episodes = 20

for i in range(num_episodes):
    obs, info = render_env.reset()
    episode_reward = 0
    frames = []

    while True:
        action, _states = model.predict(obs, deterministic=True)
        obs, reward, terminated, truncated, info = render_env.step(action)

        episode_reward += reward

        if terminated or truncated:
            print(f"Episode {i+1} done. Total reward: {episode_reward}\n")
            break
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 17       |
# |    ep_rew_mean      | 17       |
# |    exploration_rate | 0.933    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 13821    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 68       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 18.1     |
# |    ep_rew_mean      | 18.1     |
# |    exploration_rate | 0.858    |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 11290    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 145      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 24.8     |
# |    ep_rew_mean      | 24.8     |
# |    exploration_rate | 0.708    |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 13386    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 298      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 23.5     |
# |    ep_rew_mean      | 23.5     |
# |    exploration_rate | 0.632    |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 13445    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 376      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 23.4     |
# |    ep_rew_mean      | 23.4     |
# |    exploration_rate | 0.541    |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 13779    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 468      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.7     |
# |    ep_rew_mean      | 22.7     |
# |    exploration_rate | 0.467    |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 13907    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 544      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.8     |
# |    ep_rew_mean      | 22.8     |
# |    exploration_rate | 0.376    |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 14304    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 637      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 23       |
# |    ep_rew_mean      | 23       |
# |    exploration_rate | 0.279    |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 14764    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 736      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.5     |
# |    ep_rew_mean      | 22.5     |
# |    exploration_rate | 0.206    |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 14909    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 810      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.9     |
# |    ep_rew_mean      | 22.9     |
# |    exploration_rate | 0.104    |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 15371    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 914      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.6     |
# |    ep_rew_mean      | 22.6     |
# |    exploration_rate | 0.0249   |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 15470    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 995      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.7     |
# |    ep_rew_mean      | 21.7     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 13354    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1043     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.424    |
# |    n_updates        | 10       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.8     |
# |    ep_rew_mean      | 20.8     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 11952    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1082     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.254    |
# |    n_updates        | 20       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20       |
# |    ep_rew_mean      | 20       |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 10588    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1122     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.109    |
# |    n_updates        | 30       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 19.3     |
# |    ep_rew_mean      | 19.3     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 9576     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1160     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0402   |
# |    n_updates        | 39       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 19       |
# |    ep_rew_mean      | 19       |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 8983     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1216     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0224   |
# |    n_updates        | 53       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 18.6     |
# |    ep_rew_mean      | 18.6     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 8365     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1265     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0242   |
# |    n_updates        | 66       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 19       |
# |    ep_rew_mean      | 19       |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 7700     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1366     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0031   |
# |    n_updates        | 91       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 19.1     |
# |    ep_rew_mean      | 19.1     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 7215     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1454     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00172  |
# |    n_updates        | 113      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 18.9     |
# |    ep_rew_mean      | 18.9     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 6931     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1508     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.000761 |
# |    n_updates        | 126      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 18.7     |
# |    ep_rew_mean      | 18.7     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 6684     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1567     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.000437 |
# |    n_updates        | 141      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 18.3     |
# |    ep_rew_mean      | 18.3     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 88       |
# |    fps              | 6544     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1610     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.000253 |
# |    n_updates        | 152      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 18       |
# |    ep_rew_mean      | 18       |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 92       |
# |    fps              | 6410     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1655     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00047  |
# |    n_updates        | 163      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 17.7     |
# |    ep_rew_mean      | 17.7     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 96       |
# |    fps              | 6274     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1697     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.000502 |
# |    n_updates        | 174      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 17.4     |
# |    ep_rew_mean      | 17.4     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 6174     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1740     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.000369 |
# |    n_updates        | 184      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 17.1     |
# |    ep_rew_mean      | 17.1     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 104      |
# |    fps              | 6080     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1779     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.
|
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 56.9     |
# |    ep_rew_mean      | 56.9     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 432      |
# |    fps              | 4046     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 9727     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0271   |
# |    n_updates        | 2181     |
# ----------------------------------
# Episode 1 done. Total reward: 188.0
#
# Episode 2 done. Total reward: 162.0
#
# Episode 3 done. Total reward: 234.0
#
# Episode 4 done. Total reward: 170.0
#
# Episode 5 done. Total reward: 232.0
#
# Episode 6 done. Total reward: 162.0
#
# Episode 7 done. Total reward: 166.0
#
# Episode 8 done. Total reward: 192.0
#
# Episode 9 done. Total reward: 188.0
#
# Episode 10 done. Total reward: 215.0
#
# Episode 11 done. Total reward: 241.0
#
# Episode 12 done. Total reward: 158.0
#
# Episode 13 done. Total reward: 180.0
#
# Episode 14 done. Total reward: 186.0
#
# Episode 15 done. Total reward: 211.0
#
# Episode 16 done. Total reward: 201.0
#
# Episode 17 done. Total reward: 164.0
#
# Episode 18 done. Total reward: 213.0
#
# Episode 19 done. Total reward: 168.0
#
# Episode 20 done. Total reward: 256.0

# %%
import gymnasium as gym

env_ids = sorted(gym.envs.registry.keys())

from IPython.display import display, Markdown
display(Markdown("**Registered Environments:**\n" + "\n".join(f"- `{e}`" for e in env_ids)))
# Out:
# **Registered Environments:**
# - `Acrobot-v1`
# - `Ant-v2`
# - `Ant-v3`
# - `Ant-v4`
# - `Ant-v5`
# - `BipedalWalker-v3`
# - `BipedalWalkerHardcore-v3`
# - `Blackjack-v1`
# - `CarRacing-v3`
# - `CartPole-v0`
# - `CartPole-v1`
# - `CliffWalking-v0`
# - `FrozenLake-v1`
# - `FrozenLake8x8-v1`
# - `GymV21Environment-v0`
# - `GymV26Environment-v0`
# - `HalfCheetah-v2`
# - `HalfCheetah-v3`
# - `HalfCheetah-v4`
# - `HalfCheetah-v5`
# - `Hopper-v2`
# - `Hopper-v3`
# - `Hopper-v4`
# - `Hopper-v5`
# - `Humanoid-v2`
# - `Humanoid-v3`
# - `Humanoid-v4`
# - `Humanoid-v5`
# - `HumanoidStandup-v2`
# - `HumanoidStandup-v4`
# - `HumanoidStandup-v5`
# - `InvertedDoublePendulum-v2`
# - `InvertedDoublePendulum-v4`
# - `InvertedDoublePendulum-v5`
# - `InvertedPendulum-v2`
# - `InvertedPendulum-v4`
# - `InvertedPendulum-v5`
# - `LunarLander-v3`
# - `LunarLanderContinuous-v3`
# - `MountainCar-v0`
# - `MountainCarContinuous-v0`
# - `Pendulum-v1`
# - `Pusher-v2`
# - `Pusher-v4`
# - `Pusher-v5`
# - `Reacher-v2`
# - `Reacher-v4`
# - `Reacher-v5`
# - `Swimmer-v2`
# - `Swimmer-v3`
# - `Swimmer-v4`
# - `Swimmer-v5`
# - `Taxi-v3`
# - `Walker2d-v2`
# - `Walker2d-v3`
# - `Walker2d-v4`
# - `Walker2d-v5`
# - `phys2d/CartPole-v0`
# - `phys2d/CartPole-v1`
# - `phys2d/Pendulum-v0`
# - `tabular/Blackjack-v0`
# - `tabular/CliffWalking-v0`
