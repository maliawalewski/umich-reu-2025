# %%
import gymnasium as gym
from stable_baselines3 import DQN

# Create environment (no rendering)
train_env = gym.make("MountainCar-v0")

# Build DQN model with good hyperparameters
model = DQN(
    policy="MlpPolicy",
    env=train_env,
    verbose=1,
    learning_rate=1e-3,
    buffer_size=50_000,
    learning_starts=1000,
    batch_size=64,
    tau=1.0,
    gamma=0.99,
    train_freq=1,
    target_update_interval=500,
    exploration_initial_eps=1.0,
    exploration_final_eps=0.01,
    exploration_fraction=0.1,
)

# Train the model
print("Training the model...")
model.learn(total_timesteps=350_000)
print("Training complete!")

# Visualize agent performance (this part renders)
eval_env = gym.make("MountainCar-v0", render_mode="human")

print("\nRunning evaluation episodes...")
for episode in range(5):
    obs, info = eval_env.reset()
    total_reward = 0

    for step in range(200):
        action, _ = model.predict(obs, deterministic=True)
        obs, reward, terminated, truncated, info = eval_env.step(action)
        total_reward += reward

        if terminated or truncated:
            if obs[0] >= 0.5:
                print(f"Episode {episode+1}: Reached the flag! Total reward: {total_reward}")
            else:
                print(f"Episode {episode+1}: Didn't reach flag! Total reward: {total_reward}")
            break

eval_env.close()
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Training the model...
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | -200     |
# |    exploration_rate | 0.977    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 17572    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 800      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | -200     |
# |    exploration_rate | 0.955    |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 3547     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1600     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 9.6e-05  |
# |    n_updates        | 599      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | -200     |
# |    exploration_rate | 0.932    |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 2495     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2400     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 7.76e-06 |
# |    n_updates        | 1399     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | -200     |
# |    exploration_rate | 0.909    |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 2196     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 3200     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 3.74e-05 |
# |    n_updates        | 2199     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | -200     |
# |    exploration_rate | 0.887    |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 2027     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 4000     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 7.76e-07 |
# |    n_updates        | 2999     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | -200     |
# |    exploration_rate | 0.864    |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 1911     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 4800     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 3.15e-06 |
# |    n_updates        | 3799     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | -200     |
# |    exploration_rate | 0.842    |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 1849     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 5600     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 2.9e-05  |
# |    n_updates        | 4599     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | -200     |
# |    exploration_rate | 0.819    |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 1808     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 6400     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.68e-06 |
# |    n_updates        | 5399     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | -200     |
# |    exploration_rate | 0.796    |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 1775     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 7200     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 5.56e-06 |
# |    n_updates        | 6199     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | -200     |
# |    exploration_rate | 0.774    |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 1741     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 8000     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 2.63e-06 |
# |    n_updates        | 6999     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | -200     |
# |    exploration_rate | 0.751    |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 1713     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 8800     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.88e-06 |
# |    n_updates        | 7799     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | -200     |
# |    exploration_rate | 0.728    |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 1692     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 9600     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.57e-05 |
# |    n_updates        | 8599     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | -200     |
# |    exploration_rate | 0.706    |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 1683     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 10400    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 2.9e-06  |
# |    n_updates        | 9399     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | -200     |
# |    exploration_rate | 0.683    |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 1670     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 11200    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 4.1e-06  |
# |    n_updates        | 10199    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | -200     |
# |    exploration_rate | 0.661    |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 1661     |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 12000    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 2.6e-06  |
# |    n_updates        | 10999    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | -200     |
# |    exploration_rate | 0.638    |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 1654     |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 12800    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 2.17e-06 |
# |    n_updates        | 11799    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | -200     |
# |    exploration_rate | 0.615    |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 1644     |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 13600    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.57e-05 |
# |    n_updates        | 12599    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | -200     |
# |    exploration_rate | 0.593    |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 1640     |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 14400    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 2.76e-06 |
# |    n_updates        | 13399    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | -200     |
# |    exploration_rate | 0.57     |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 1633     |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 15200    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 2.18e-06 |
# |    n_updates        | 14199    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | -200     |
# |    exploration_rate | 0.547    |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 1629     |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 16000    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 3.96e-06 |
# |    n_updates        | 14999    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | -200     |
# |    exploration_rate | 0.525    |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 1623     |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 16800    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 4.68e-06 |
# |    n_updates        | 15799    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | -200     |
# |    exploration_rate | 0.502    |
# | time/               |          |
# |    episodes         | 88       |
# |    fps              | 1618     |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 17600    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.68e-05 |
# |    n_updates        | 16599    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | -200     |
# |    exploration_rate | 0.48     |
# | time/               |          |
# |    episodes         | 92       |
# |    fps              | 1612     |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 18400    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.13e-05 |
# |    n_updates        | 17399    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | -200     |
# |    exploration_rate | 0.457    |
# | time/               |          |
# |    episodes         | 96       |
# |    fps              | 1608     |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 19200    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 5.24e-06 |
# |    n_updates        | 18199    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | -200     |
# |    exploration_rate | 0.434    |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 1603     |
# |    time_elapsed     | 12       |
# |    total_timesteps  | 20000    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 2.73e-06 |
# |    n_updates        | 18999    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | -200     |
# |    exploration_rate | 0.412    |
# | time/               |          |
# |    episodes         | 104      |
# |    fps              | 1591     |
# |    time_elapsed     | 13       |
# |    total_timesteps  | 20800    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 7.56e-06 |
# |    n_updates        | 19799    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | -200     |
# |    exploration_rate | 0.389    |
# | time/               |          |
# |    episodes         | 108      |
# |    fps              | 1588     |
# |    time_elapsed     | 13       |
# |    total_timesteps  | 21600    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.02e-05 |
# |    n_updates        | 20599    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | -200     |
# |    exploration_rate | 0.366    |
# | time/               |          |
# |    episodes         | 112      |
# |    fps              | 1585     |
# |    time_elapsed     | 14       |
# |    total_timesteps  | 22400    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 2
    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 198      |
# |    ep_rew_mean      | -198     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 276      |
# |    fps              | 1524     |
# |    time_elapsed     | 36       |
# |    total_timesteps  | 55046    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.000662 |
# |    n_updates        | 54045    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 198      |
# |    ep_rew_mean      | -198     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 280      |
# |    fps              | 1523     |
# |    time_elapsed     | 36       |
# |    total_timesteps  | 55846    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 4.34e-05 |
# |    n_updates        | 54845    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 198      |
# |    ep_rew_mean      | -198     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 284      |
# |    fps              | 1522     |
# |    time_elapsed     | 37       |
# |    total_timesteps  | 56646    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 4.6e-05  |
# |    n_updates        | 55645    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 198      |
# |    ep_rew_mean      | -198     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 288      |
# |    fps              | 1522     |
# |    time_elapsed     | 37       |
# |    total_timesteps  | 57446    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 4.28e-05 |
# |    n_updates        | 56445    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 199      |
# |    ep_rew_mean      | -199     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 292      |
# |    fps              | 1522     |
# |    time_elapsed     | 38       |
# |    total_timesteps  | 58246    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 2.64e-05 |
# |    n_updates        | 57245    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 199      |
# |    ep_rew_mean      | -199     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 296      |
# |    fps              | 1521     |
# |    time_elapsed     | 38       |
# |    total_timesteps  | 59046    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 7.55e-05 |
# |    n_updates        | 58045    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 199      |
# |    ep_rew_mean      | -199     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 300      |
# |    fps              | 1520     |
# |    time_elapsed     | 39       |
# |    total_timesteps  | 59846    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.932    |
# |    n_updates        | 58845    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | -200     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 304      |
# |    fps              | 1520     |
# |    time_elapsed     | 39       |
# |    total_timesteps  | 60646    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 5.39e-05 |
# |    n_updates        | 59645    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | -200     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 308      |
# |    fps              | 1519     |
# |    time_elapsed     | 40       |
# |    total_timesteps  | 61446    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.000103 |
# |    n_updates        | 60445    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | -200     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 312      |
# |    fps              | 1518     |
# |    time_elapsed     | 40       |
# |    total_timesteps  | 62246    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.98e-05 |
# |    n_updates        | 61245    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | -200     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 316      |
# |    fps              | 1518     |
# |    time_elapsed     | 41       |
# |    total_timesteps  | 63046    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.000204 |
# |    n_updates        | 62045    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | -200     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 320      |
# |    fps              | 1517     |
# |    time_elapsed     | 42       |
# |    total_timesteps  | 63846    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.000109 |
# |    n_updates        | 62845    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | -200     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 324      |
# |    fps              | 1517     |
# |    time_elapsed     | 42       |
# |    total_timesteps  | 64646    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 4.75e-05 |
# |    n_updates        | 63645    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | -200     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 328      |
# |    fps              | 1517     |
# |    time_elapsed     | 43       |
# |    total_timesteps  | 65446    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.000162 |
# |    n_updates        | 64445    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | -200     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 332      |
# |    fps              | 1516     |
# |    time_elapsed     | 43       |
# |    total_timesteps  | 66246    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.000136 |
# |    n_updates        | 65245    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | -200     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 336      |
# |    fps              | 1514     |
# |    time_elapsed     | 44       |
# |    total_timesteps  | 67046    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00199  |
# |    n_updates        | 66045    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | -200     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 340      |
# |    fps              | 1514     |
# |    time_elapsed     | 44       |
# |    total_timesteps  | 67846    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.000222 |
# |    n_updates        | 66845    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | -200     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 344      |
# |    fps              | 1513     |
# |    time_elapsed     | 45       |
# |    total_timesteps  | 68646    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.000183 |
# |    n_updates        | 67645    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | -200     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 348      |
# |    fps              | 1513     |
# |    time_elapsed     | 45       |
# |    total_timesteps  | 69446    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 9.29e-05 |
# |    n_updates        | 68445    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | -200     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 352      |
# |    fps              | 1512     |
# |    time_elapsed     | 46       |
# |    total_timesteps  | 70246    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.000216 |
# |    n_updates        | 69245    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | -200     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 356      |
# |    fps              | 1511     |
# |    time_elapsed     | 46       |
# |    total_timesteps  | 71046    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.000509 |
# |    n_updates        | 70045    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | -200     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 360      |
# |    fps              | 1511     |
# |    time_elapsed     | 47       |
# |    total_timesteps  | 71846    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00015  |
# |    n_updates        | 70845    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | -200     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 364      |
# |    fps              | 1511     |
# |    time_elapsed     | 48       |
# |    total_timesteps  | 72646    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00397  |
# |    n_updates        | 71645    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | -200     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 368      |
# ...
# |    ep_len_mean      | 137      |
# |    ep_rew_mean      | -137     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2132     |
# |    fps              | 1477     |
# |    time_elapsed     | 226      |
# |    total_timesteps  | 334182   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.857    |
# |    n_updates        | 333181   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 136      |
# |    ep_rew_mean      | -136     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2136     |
# |    fps              | 1477     |
# |    time_elapsed     | 226      |
# |    total_timesteps  | 334652   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.761    |
# |    n_updates        | 333651   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 136      |
# |    ep_rew_mean      | -136     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2140     |
# |    fps              | 1477     |
# |    time_elapsed     | 226      |
# |    total_timesteps  | 335094   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 3.85     |
# |    n_updates        | 334093   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 136      |
# |    ep_rew_mean      | -136     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2144     |
# |    fps              | 1477     |
# |    time_elapsed     | 227      |
# |    total_timesteps  | 335663   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.769    |
# |    n_updates        | 334662   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 136      |
# |    ep_rew_mean      | -136     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2148     |
# |    fps              | 1477     |
# |    time_elapsed     | 227      |
# |    total_timesteps  | 336142   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.709    |
# |    n_updates        | 335141   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 136      |
# |    ep_rew_mean      | -136     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2152     |
# |    fps              | 1477     |
# |    time_elapsed     | 227      |
# |    total_timesteps  | 336611   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.32     |
# |    n_updates        | 335610   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 136      |
# |    ep_rew_mean      | -136     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2156     |
# |    fps              | 1477     |
# |    time_elapsed     | 228      |
# |    total_timesteps  | 337125   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 4.25     |
# |    n_updates        | 336124   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 136      |
# |    ep_rew_mean      | -136     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2160     |
# |    fps              | 1477     |
# |    time_elapsed     | 228      |
# |    total_timesteps  | 337662   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 7.69     |
# |    n_updates        | 336661   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 135      |
# |    ep_rew_mean      | -135     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2164     |
# |    fps              | 1477     |
# |    time_elapsed     | 228      |
# |    total_timesteps  | 338131   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.713    |
# |    n_updates        | 337130   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 135      |
# |    ep_rew_mean      | -135     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2168     |
# |    fps              | 1477     |
# |    time_elapsed     | 229      |
# |    total_timesteps  | 338684   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.05     |
# |    n_updates        | 337683   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 136      |
# |    ep_rew_mean      | -136     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2172     |
# |    fps              | 1477     |
# |    time_elapsed     | 229      |
# |    total_timesteps  | 339234   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 6.33     |
# |    n_updates        | 338233   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 135      |
# |    ep_rew_mean      | -135     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2176     |
# |    fps              | 1477     |
# |    time_elapsed     | 229      |
# |    total_timesteps  | 339792   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.892    |
# |    n_updates        | 338791   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 136      |
# |    ep_rew_mean      | -136     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2180     |
# |    fps              | 1477     |
# |    time_elapsed     | 230      |
# |    total_timesteps  | 340268   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.777    |
# |    n_updates        | 339267   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 135      |
# |    ep_rew_mean      | -135     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2184     |
# |    fps              | 1477     |
# |    time_elapsed     | 230      |
# |    total_timesteps  | 340748   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 3.97     |
# |    n_updates        | 339747   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 136      |
# |    ep_rew_mean      | -136     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2188     |
# |    fps              | 1477     |
# |    time_elapsed     | 230      |
# |    total_timesteps  | 341283   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.64     |
# |    n_updates        | 340282   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 136      |
# |    ep_rew_mean      | -136     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2192     |
# |    fps              | 1477     |
# |    time_elapsed     | 231      |
# |    total_timesteps  | 341856   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.13     |
# |    n_updates        | 340855   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 136      |
# |    ep_rew_mean      | -136     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2196     |
# |    fps              | 1477     |
# |    time_elapsed     | 231      |
# |    total_timesteps  | 342448   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.16     |
# |    n_updates        | 341447   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 136      |
# |    ep_rew_mean      | -136     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2200     |
# |    fps              | 1477     |
# |    time_elapsed     | 232      |
# |    total_timesteps  | 342920   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.11     |
# |    n_updates        | 341919   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 135      |
# |    ep_rew_mean      | -135     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2204     |
# |    fps              | 1477     |
# |    time_elapsed     | 232      |
# |    total_timesteps  | 343491   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.04     |
# |    n_updates        | 342490   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 133      |
# |    ep_rew_mean      | -133     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2208     |
# |    fps              | 1477     |
# |    time_elapsed     | 232      |
# |    total_timesteps  | 344051   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 4.84     |
# |    n_updates        | 343050   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 132      |
# |    ep_rew_mean      | -132     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2212     |
# |    fps              | 1477     |
# |    time_elapsed     | 233      |
# |    total_timesteps  | 344593   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.07     |
# |    n_updates        | 343592   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 130      |
# |    ep_rew_mean      | -130     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2216     |
# |    fps              | 1477     |
# |    time_elapsed     | 233      |
# |    total_timesteps  | 344977   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.805    |
# |    n_updates        | 343976   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 130      |
# |    ep_rew_mean      | -130     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2220     |
# |    fps              | 1477     |
# |    time_elapsed     | 233      |
# |    total_timesteps  | 345495   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 3.77     |
# |    n_updates        | 344494   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 130      |
# |    ep_rew_mean      | -130     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2224     |
# |    fps              | 1477     |
# |    time_elapsed     | 234      |
# |    total_timesteps  | 346002   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 2.22     |
# |    n_updates        | 345001   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 129      |
# |    ep_rew_mean      | -129     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2228     |
# |    fps              | 1477     |
# |    time_elapsed     | 234      |
# |    total_timesteps  | 346475   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.918    |
# |    n_updates        | 345474   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 128      |
# |    ep_rew_mean      | -128     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2232     |
# |    fps              | 1477     |
# |    time_elapsed     | 234      |
# |    total_timesteps  | 346983   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 12.6     |
# |    n_updates        | 345982   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 130      |
# |    ep_rew_mean      | -130     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2236     |
# |    fps              | 1477     |
# |    time_elapsed     | 235      |
# |    total_timesteps  | 347683   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 4.33     |
# |    n_updates        | 346682   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 132      |
# |    ep_rew_mean      | -132     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2240     |
# |    fps              | 1477     |
# |    time_elapsed     | 235      |
# |    total_timesteps  | 348253   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 5.12     |
# |    n_updates        | 347252   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 132      |
# |    ep_rew_mean      | -132     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2244     |
# |    fps              | 1477     |
# |    time_elapsed     | 236      |
# |    total_timesteps  | 348848   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 2.58     |
# |    n_updates        | 347847   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 134      |
# |    ep_rew_mean      | -134     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2248     |
# |    fps              | 1477     |
# |    time_elapsed     | 236      |
# |    total_timesteps  | 349501   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 8.36     |
# |    n_updates        | 348500   |
# ----------------------------------
# Training complete!
#
# Running evaluation episodes...
# Episode 1: Reached the flag! Total reward: -158.0
# Episode 2: Reached the flag! Total reward: -105.0
# Episode 3: Reached the flag! Total reward: -95.0
# Episode 4: Reached the flag! Total reward: -157.0
# Episode 5: Reached the flag! Total reward: -161.0
